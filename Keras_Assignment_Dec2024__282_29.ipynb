# %% [markdown]
# # CW1 - Multimodal IMDB Analysis with Keras
#
# ## Introduction
#
# In this assignment you will be provided a dataset containing a selection of films together with their posters in JPEG image format and their overviews in text format from the Internet Movie Database.
#
# ![Example](https://i.ibb.co/J3trT62/Screenshot-2024-09-22-214753.png)
#
# You will be analysing this dataset by implementing and training two models: a **CNN** and an **LSTM**.
#
# The CNN must classify film posters by the genre. Independently, the LSTM must classify film overviews by the genre. Finally, you will evaluate and critically comment your results in a short report. (Which of the two models was better at classifying films?)
#
# ## Structure of the assignment
#
# This assignment is broken up into sections and you need to complete each section successively. The sections are the following:
#
# 1. Data Processing
#
#   1.a. Image processing of the posters
#
#   1.b. Natural language processing of the overviews
#
# 2. Definition of the models
#
#   2.a. CNN for the posters
#
#   2.b. LSTM for the overviews
#
# 3. Training of the models
# 4. Evaluation of the models
#
# In addition to this coding exercise, you must write a **2-3 pages** report analysing and critically evaluating your model's results. Marks for the report will be awarded for depth of analysis and critical thinking skills. You should consider how well your model performs and WHY it does that—give specific examples and comment on their importance.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Data Processing
#
# Warning: running the following cell can take some time.

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multimodal_IMDB_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multimodal_IMDB_dataset/Images /tmp/Multimodal_IMDB_dataset/
# Out:
#         192.14M 100%  672.38kB/s    0:04:39 (xfr#7916, to-chk=0/7917)
# mkdir: cannot create directory ‘/tmp/Multimodal_IMDB_dataset’: File exists
#               0   0%    0.00kB/s    0:00:00 (xfr#0, to-chk=0/7917)

# %%
# CodeGrade Tag Init3
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres
csv_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv"
dataset = pd.read_csv(csv_loc)

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1).columns)

# List of overviews
overviews_train = np.array(data_train['Overview'])
overviews_test = np.array(data_test['Overview'])

# Build the file locations for the images
img_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]

# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# %% [markdown]
# ### 1.a. Image processing of the posters

# %%
# CodeGrade Tag Init4
# Do not edit, remove, or copy this cell

# Create the initial datasets of film posters
list_posters_train_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
list_posters_valid_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# * Create a function called ```img_process``` that converts the images to float32 datatype and resizes them to 64x64 pixels

# %%
# CodeGrade Tag Ex1a-i
### Create a function called img_process that converts the images to
### float32 datatype and resizes them to 64x64 pixels

def img_process(image, label):
  """Processes an image by resizing it and converting it to float32.

  Args:
    image: A TensorFlow tensor representing the image.
    label: The image label.

  Returns:
    A tuple containing the processed image and label.
  """
  image = tf.image.resize(image, [64, 64])  # Resize to 64x64 pixels
  image = tf.cast(image, dtype=tf.float32)  # Convert to float32

  return image, label

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the posters. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1a-ii
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64.

# Adjust to process data in batches
posters_train_ds = (
    list_posters_train_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Apply parse_image in parallel
    .batch(64)  # Batch the data
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Vectorized img_process
    .cache()  # Cache data
    .prefetch(tf.data.AUTOTUNE)  # Optimize prefetching
)

posters_valid_ds = (
    list_posters_valid_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(64)
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()
    .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ### 1.b. Natural Language processing of the overviews

# %%
# CodeGrade Tag Init5
# Do not edit, remove, or copy this cell

# Create the initial datasets of the film overviews
list_overviews_train_ds = tf.data.Dataset.from_tensor_slices((overviews_train, labels_train))
list_overviews_valid_ds = tf.data.Dataset.from_tensor_slices((overviews_test, labels_test))

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the overviews.**

# %%
# CodeGrade Tag Ex1b-i
### Construct the training and validation datasets. Use a batch size of 64.

overviews_train_ds = list_overviews_train_ds.batch(64).prefetch(tf.data.AUTOTUNE)  # Batch size is 64

# Create the validation dataset and set a batch size of 64
overviews_valid_ds = list_overviews_valid_ds.batch(64).prefetch(tf.data.AUTOTUNE)  # Batch size is 64

# %% [markdown]
# * Build the vocabulary of the model by calling the ``encoder.adapt()`` method on the film overviews train data.

# %%
# CodeGrade Tag Ex1b-ii
### Build the vocabulary of the model by calling the encoder.adapt() method on
### the film overviews train data.

VOCAB_SIZE = 10000

encoder = tf.keras.layers.TextVectorization(max_tokens=VOCAB_SIZE)

encoder.adapt(overviews_train_ds.map(lambda text, label: text))

# %% [markdown]
# * Print the first 200 words of the vocabulary you obtained.

# %%
# CodeGrade Tag Ex1b-iii
### Print the first 200 words of the vocabulary you obtained.

vocab = np.array(encoder.get_vocabulary())
print(vocab[:200])
# Out:
# ['' '[UNK]' 'a' 'the' 'to' 'of' 'and' 'in' 'his' 'is' 'an' 'with' 'her'
#  'for' 'on' 'he' 'their' 'who' 'by' 'from' 'when' 'as' 'that' 'after'
#  'young' 'life' 'they' 'at' 'man' 'two' 'new' 'him' 'are' 'but' 'into'
#  'has' 'she' 'up' 'woman' 'love' 'one' 'family' 'out' 'find' 'friends'
#  'must' 'be' 'them' 'finds' 'story' 'world' 'it' 'school' 'where' 'about'
#  'while' 'have' 'group' 'years' 'girl' 'father' 'home' 'wife' 'war' 'town'
#  'lives' 'help' 'three' 'becomes' 'get' 'during' 'all' 'back' 'son' 'city'
#  'boy' 'only' 'himself' 'which' 'between' 'gets' 'time' 'former' 'high'
#  'york' 'murder' 'against' 'team' 'american' 'own' 'small' 'other' 'takes'
#  'friend' 'college' 'being' 'mother' 'police' 'down' 'daughter' 'before'
#  'its' 'tries' 'this' 'can' 'was' 'order' 'falls' 'become' 'death' 'will'
#  'take' 'agent' 'together' 'save' 'old' 'not' 'goes' 'set' 'relationship'
#  'way' 'through' 'over' 'first' 'husband' 'people' 'killer' 'off'
#  'returns' 'more' 'living' 'couple' 'what' 'meets' 'go' 'forced' 'brother'
#  'discovers' 'stop' 'make' 'best' 'parents' 'hes' 'comes' 'each' 'drug'
#  'begins' 'been' 'work' 'us' 'secret' 'now' 'detective' 'mysterious' 'day'
#  'job' 'house' 'evil' 'past' 'just' 'local' 'four' 'cop' 'turns' 'men'
#  'film' 'soon' 'black' 'women' 'whose' 'movie' 'live' 'so' 'series' 'most'
#  'run' 'trying' 'student' 'prison' 'discover' 'or' 'married' 'try'
#  'around' 'true' 'trip' 'teenage' 'killed' 'earth' 'wants' 'than' 'sent'
#  'left' 'another' 'some' 'herself' 'fight' 'last' 'brothers' 'sister']
# ['' '[UNK]' 'a' 'the' 'to' 'of' 'and' 'in' 'his' 'is' 'an' 'with' 'her'
#  'for' 'on' 'he' 'their' 'who' 'by' 'when' 'from' 'as' 'that' 'after'
#  'young' 'life' 'they' 'man' 'at' 'new' 'him' 'two' 'are' 'but' 'she' 'up'
#  'has' 'into' 'one' 'out' 'family' 'woman' 'love' 'find' 'be' 'must' 'it'
#  'finds' 'friends' 'world' 'school' 'them' 'story' 'where' 'about' 'group'
#  'have' 'while' 'girl' 'father' 'years' 'town' 'lives' 'war' 'becomes'
#  'home' 'wife' 'three' 'back' 'during' 'get' 'city' 'all' 'help' 'boy'
#  'high' 'only' 'himself' 'son' 'gets' 'between' 'which' 'team' 'york'
#  'time' 'tries' 'daughter' 'against' 'other' 'takes' 'murder' 'police'
#  'former' 'can' 'falls' 'its' 'friend' 'college' 'american' 'before' 'old'
#  'down' 'small' 'mother' 'own' 'order' 'become' 'death' 'was' 'being'
#  'will' 'this' 'goes' 'save' 'take' 'together' 'set' 'meets' 'first'
#  'people' 'agent' 'through' 'off' 'husband' 'each' 'way' 'not' 'more'
#  'returns' 'over' 'make' 'brother' 'go' 'couple' 'relationship'
#  'mysterious' 'hes' 'best' 'living' 'job' 'discovers' 'what' 'us' 'comes'
#  'secret' 'day' 'begins' 'drug' 'stop' 'men' 'work' 'past' 'now' 'just'
#  'cop' 'been' 'killer' 'house' 'detective' 'parents' 'married' 'local'
#  'four' 'evil' 'sent' 'student' 'than' 'soon' 'women' 'turns' 'prison'
#  'officer' 'forced' 'so' 'trying' 'discover' 'there' 'movie' 'another'
#  'or' 'black' 'try' 'some' 'film' 'around' 'teenage' 'live' 'fight'
#  'brothers' 'run' 'herself' 'come' 'whose' 'killed' 'series' 'most'
#  'battle' 'then' 'sister' 'crime']

# %% [markdown]
# # 2. Definition of the models
#
# ### 2.a. CNN
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture shown in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a-i
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

def build_cnn_model():
    """Builds the CNN model using the Keras Functional API.

    Returns:
        The compiled CNN model.
    """
    input_tensor = Input(shape=(64, 64, 3), name='Input')

    # Convolutional layers
    x = Conv2D(16, (3, 3), activation='relu', strides=2, padding='same', name='Conv0')(input_tensor)
    x = Dropout(0.2, name='Drop1')(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same', name='Conv1')(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same', name='Conv2')(x)
    x = Dropout(0.2, name='Drop2')(x)
    x = MaxPooling2D((2, 2), name='Pool1')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv3')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv4')(x)
    x = Dropout(0.2, name='Drop3')(x)
    x = MaxPooling2D((2, 2), name='Pool2')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='Conv5')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='Conv6')(x)
    x = Dropout(0.2, name='Drop4')(x)
    x = MaxPooling2D((2, 2), name='Pool3')(x)

    # Flatten and dense layers
    x = Flatten(name='Flat')(x)
    x = Dense(1024, activation='relu', name='FC1')(x)
    x = Dropout(0.5, name='Drop5')(x)
    x = Dense(1024, activation='relu', name='FC2')(x)
    x = Dropout(0.5, name='Drop6')(x)

    # Output layer
    output_tensor = Dense(25, activation='sigmoid', name='Output')(x)

    # Create the model
    model = Model(inputs=input_tensor, outputs=output_tensor, name='model')
    return model

cnn_model = build_cnn_model()

# %% [markdown]
# * Print the model summary and confirm it has the same architecture as the one provided.

# %%
# CodeGrade Tag Ex2a-ii
### Print the model summary and confirm it has the same architecture as the one
### provided.

cnn_model.summary()
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv0 (Conv2D)                       │ (None, 32, 32, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop1 (Dropout)                      │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv1 (Conv2D)                       │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv2 (Conv2D)                       │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop2 (Dropout)                      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool1 (MaxPooling2D)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv3 (Conv2D)                       │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv4 (Conv2D)                       │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop3 (Dropout)                      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool2 (MaxPooling2D)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv5 (Conv2D)                       │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv6 (Conv2D)                       │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop4 (Dropout)                      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool3 (MaxPooling2D)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Flat (Flatten)                       │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC1 (Dense)                          │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop5 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC2 (Dense)                          │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop6 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 25)                  │          25,625 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv0 (Conv2D)                       │ (None, 32, 32, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop1 (Dropout)                      │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv1 (Conv2D)                       │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv2 (Conv2D)                       │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop2 (Dropout)                      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool1 (MaxPooling2D)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv3 (Conv2D)                       │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv4 (Conv2D)                       │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop3 (Dropout)                      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool2 (MaxPooling2D)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv5 (Conv2D)                       │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv6 (Conv2D)                       │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop4 (Dropout)                      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool3 (MaxPooling2D)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Flat (Flatten)                       │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC1 (Dense)                          │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop5 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC2 (Dense)                          │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop6 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 25)                  │          25,625 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2a-iii
### Compile the model using the Adam Optimizer with a learning rate of 1e-4 and
### binary crossentropy loss function. For the metrics, use the Precision and
### Recall functions.

cnn_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[Precision(), Recall()]
)

# %% [markdown]
# ### 2.b. LSTM model
#
# * Set up the embedding layer by using ```tf.keras.layers.Embedding```. The ```input_dim``` is the length of the vocab, and the ```output_dim``` must be **265**. You should also set ```mask_zero=True```.

# %%
# CodeGrade Tag Ex2b-i
### Set up the embedding layer. The input_dim is the length of the vocab, and
### the output_dim must be 256. You should also set mask_zero=True.

embedder = tf.keras.layers.Embedding(input_dim=VOCAB_SIZE, output_dim=256, mask_zero=True)

# %% [markdown]
# * Use ```tf.keras.Sequential``` to build a keras sequential model, with the following layers:
#
#
#
#   1.   encoder
#   2.   embedder
#   3.   biLSTM layer with 256 units, dropout 0.5, recurrent dropout 0.2 (make sure to use the right ```return_sequences``` parametre to be able to stack this layer with the following BiLSTM)
#   4.   biLSTM layer with 128 units, dropout 0.5, recurrent dropout 0.2
#   5.   dense layer with 128 units and relu activation function
#   6.   dropout with rate 0.8
#   7.   dense output layer with 25 units and sigmoid activation function

# %%
# CodeGrade Tag Ex2b-ii
### Build a keras sequential model, with the layers provided above.

lstm_model = tf.keras.Sequential([
    encoder,
    embedder,
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256, dropout=0.5, recurrent_dropout=0.2, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5, recurrent_dropout=0.2)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.8),
    tf.keras.layers.Dense(25, activation='sigmoid')
])

lstm_model.build((None,))

# %% [markdown]
# * Print the model summary and confirm is has the same architecture as the outline provided above.

# %%
# CodeGrade Tag Ex2b-iii
### Print the model summary and confirm is has the same architecture as the
### outline provided above.
lstm_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_vectorization                   │ (None, None)                │               0 │
# │ (TextVectorization)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, None, 256)           │       2,560,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, None, 512)           │       1,050,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 256)                 │         656,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 25)                  │           3,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_vectorization_1                 │ (None, None)                │               0 │
# │ (TextVectorization)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, None, 256)           │       2,560,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_2 (Bidirectional)      │ (None, None, 512)           │       1,050,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_3 (Bidirectional)      │ (None, 256)                 │         656,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 25)                  │           3,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Compile the model with binary crossentropy loss and the adam optimizer. For the metrics, use the Precision and Recall functions.

# %%
# CodeGrade Tag Ex2b-iv
### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall

# Compile the LSTM model with corrected metrics
lstm_model.compile(
    optimizer=Adam(learning_rate=1e-4),  # Optimizer with a specific learning rate
    loss='binary_crossentropy',  # Suitable for binary classification
    metrics=[
        Precision(name='precision'),  # Precision metric
        Recall(name='recall')         # Recall metric
    ]
)

# %% [markdown]
# # 3. Training of the models
#
# * **For each model, create a Checkpoint Callback that saves the weights of the best performing epoch, based on the validation loss.**

# %%
# CodeGrade Tag Ex3a-i
### Create two ModelCheckpoint callbacks to store the bext weights from each
### model, both based on the validation loss.

checkpoint_cnn_filepath = '/content/checkpoint_cnn.weights.h5'
checkpoint_lstm_filepath = '/content/checkpoint_lstm.weights.h5'

from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_cnn_callback = ModelCheckpoint(
    filepath=checkpoint_cnn_filepath,
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1,
    save_weights_only=True
)

checkpoint_lstm_callback = ModelCheckpoint(
    filepath=checkpoint_lstm_filepath,
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1,
    save_weights_only=True
)

# %% [markdown]
# * **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3a-ii
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.01))

lr_callback = LearningRateScheduler(scheduler)

# %% [markdown]
# ### 3.a. CNN training
#
# * **Train the CNN model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3a-iii
### Train the model for 40 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

cnn_history = cnn_model.fit(
    posters_train_ds,
    validation_data=posters_valid_ds,
    epochs=40,
    callbacks=[checkpoint_cnn_callback, lr_callback]
)
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 2.3945 - precision: 0.2142 - recall: 0.3280
# Epoch 1: val_loss improved from inf to 0.34936, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 38s 322ms/step - loss: 2.3764 - precision: 0.2149 - recall: 0.3275 - val_loss: 0.3494 - val_precision: 0.5620 - val_recall: 0.3059 - learning_rate: 1.0000e-04
# Epoch 2/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3021 - precision: 0.3950 - recall: 0.2452
# Epoch 2: val_loss did not improve from 0.34936
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.3017 - precision: 0.3959 - recall: 0.2452 - val_loss: 0.3524 - val_precision: 0.5642 - val_recall: 0.3271 - learning_rate: 1.0000e-04
# Epoch 3/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2782 - precision: 0.4468 - recall: 0.2395
# Epoch 3: val_loss did not improve from 0.34936
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2781 - precision: 0.4471 - recall: 0.2394 - val_loss: 0.3539 - val_precision: 0.5642 - val_recall: 0.3604 - learning_rate: 1.0000e-04
# Epoch 4/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2682 - precision: 0.4761 - recall: 0.2377
# Epoch 4: val_loss did not improve from 0.34936
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2681 - precision: 0.4764 - recall: 0.2378 - val_loss: 0.3582 - val_precision: 0.5647 - val_recall: 0.3651 - learning_rate: 1.0000e-04
# Epoch 5/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2611 - precision: 0.4978 - recall: 0.2417
# Epoch 5: val_loss did not improve from 0.34936
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2610 - precision: 0.4982 - recall: 0.2417 - val_loss: 0.3514 - val_precision: 0.5612 - val_recall: 0.3717 - learning_rate: 1.0000e-04
# Epoch 6/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2557 - precision: 0.5040 - recall: 0.2367
# Epoch 6: val_loss improved from 0.34936 to 0.34620, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2556 - precision: 0.5049 - recall: 0.2371 - val_loss: 0.3462 - val_precision: 0.5589 - val_recall: 0.3767 - learning_rate: 1.0000e-04
# Epoch 7/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2546 - precision: 0.5140 - recall: 0.2473
# Epoch 7: val_loss improved from 0.34620 to 0.34451, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2545 - precision: 0.5143 - recall: 0.2473 - val_loss: 0.3445 - val_precision: 0.5651 - val_recall: 0.3674 - learning_rate: 1.0000e-04
# Epoch 8/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2501 - precision: 0.5310 - recall: 0.2446
# Epoch 8: val_loss improved from 0.34451 to 0.34059, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2501 - precision: 0.5312 - recall: 0.2446 - val_loss: 0.3406 - val_precision: 0.5689 - val_recall: 0.3591 - learning_rate: 1.0000e-04
# Epoch 9/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2481 - precision: 0.5215 - recall: 0.2369
# Epoch 9: val_loss improved from 0.34059 to 0.33726, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2481 - precision: 0.5218 - recall: 0.2371 - val_loss: 0.3373 - val_precision: 0.5672 - val_recall: 0.3644 - learning_rate: 1.0000e-04
# Epoch 10/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2463 - precision: 0.5350 - recall: 0.2485
# Epoch 10: val_loss improved from 0.33726 to 0.33649, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2462 - precision: 0.5351 - recall: 0.2485 - val_loss: 0.3365 - val_precision: 0.5613 - val_recall: 0.3681 - learning_rate: 1.0000e-04
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2452 - precision: 0.5309 - recall: 0.2377
# Epoch 11: val_loss improved from 0.33649 to 0.33390, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2452 - precision: 0.5310 - recall: 0.2378 - val_loss: 0.3339 - val_precision: 0.5656 - val_recall: 0.3647 - learning_rate: 9.9005e-05
# Epoch 12/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2435 - precision: 0.5389 - recall: 0.2510
# Epoch 12: val_loss improved from 0.33390 to 0.32941, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2435 - precision: 0.5391 - recall: 0.2510 - val_loss: 0.3294 - val_precision: 0.5663 - val_recall: 0.3631 - learning_rate: 9.8020e-05
# Epoch 13/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2415 - precision: 0.5413 - recall: 0.2441
# Epoch 13: val_loss improved from 0.32941 to 0.32532, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2415 - precision: 0.5420 - recall: 0.2445 - val_loss: 0.3253 - val_precision: 0.5718 - val_recall: 0.3568 - learning_rate: 9.7045e-05
# Epoch 14/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2415 - precision: 0.5462 - recall: 0.2432
# Epoch 14: val_loss improved from 0.32532 to 0.31980, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2415 - precision: 0.5464 - recall: 0.2434 - val_loss: 0.3198 - val_precision: 0.5808 - val_recall: 0.3399 - learning_rate: 9.6079e-05
# Epoch 15/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2404 - precision: 0.5451 - recall: 0.2497
# Epoch 15: val_loss improved from 0.31980 to 0.31846, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2403 - precision: 0.5457 - recall: 0.2499 - val_loss: 0.3185 - val_precision: 0.5767 - val_recall: 0.3505 - learning_rate: 9.5123e-05
# Epoch 16/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2381 - precision: 0.5596 - recall: 0.2559
# Epoch 16: val_loss improved from 0.31846 to 0.30778, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2381 - precision: 0.5599 - recall: 0.2559 - val_loss: 0.3078 - val_precision: 0.5766 - val_recall: 0.3423 - learning_rate: 9.4176e-05
# Epoch 17/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2380 - precision: 0.5656 - recall: 0.2591
# Epoch 17: val_loss improved from 0.30778 to 0.30713, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2380 - precision: 0.5658 - recall: 0.2591 - val_loss: 0.3071 - val_precision: 0.5826 - val_recall: 0.3231 - learning_rate: 9.3239e-05
# Epoch 18/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2382 - precision: 0.5572 - recall: 0.2469
# Epoch 18: val_loss improved from 0.30713 to 0.30501, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2381 - precision: 0.5578 - recall: 0.2475 - val_loss: 0.3050 - val_precision: 0.5852 - val_recall: 0.3145 - learning_rate: 9.2312e-05
# Epoch 19/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2368 - precision: 0.5571 - recall: 0.2413
# Epoch 19: val_loss improved from 0.30501 to 0.30405, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2368 - precision: 0.5575 - recall: 0.2417 - val_loss: 0.3041 - val_precision: 0.5874 - val_recall: 0.2910 - learning_rate: 9.1393e-05
# Epoch 20/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2359 - precision: 0.5653 - recall: 0.2555
# Epoch 20: val_loss improved from 0.30405 to 0.30051, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2358 - precision: 0.5656 - recall: 0.2557 - val_loss: 0.3005 - val_precision: 0.5972 - val_recall: 0.3128 - learning_rate: 9.0484e-05
# Epoch 21/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2353 - precision: 0.5671 - recall: 0.2448
# Epoch 21: val_loss improved from 0.30051 to 0.29492, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2353 - precision: 0.5675 - recall: 0.2452 - val_loss: 0.2949 - val_precision: 0.5958 - val_recall: 0.2880 - learning_rate: 8.9583e-05
# Epoch 22/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2354 - precision: 0.5778 - recall: 0.2478
# Epoch 22: val_loss improved from 0.29492 to 0.29444, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2354 - precision: 0.5783 - recall: 0.2482 - val_loss: 0.2944 - val_precision: 0.5863 - val_recall: 0.2708 - learning_rate: 8.8692e-05
# Epoch 23/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2333 - precision: 0.5746 - recall: 0.2552
# Epoch 23: val_loss improved from 0.29444 to 0.29141, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2332 - precision: 0.5750 - recall: 0.2554 - val_loss: 0.2914 - val_precision: 0.5860 - val_recall: 0.2794 - learning_rate: 8.7810e-05
# Epoch 24/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2335 - precision: 0.5857 - recall: 0.2620
# Epoch 24: val_loss did not improve from 0.29141
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2335 - precision: 0.5859 - recall: 0.2621 - val_loss: 0.2915 - val_precision: 0.5882 - val_recall: 0.2900 - learning_rate: 8.6936e-05
# Epoch 25/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2318 - precision: 0.5834 - recall: 0.2639
# Epoch 25: val_loss did not improve from 0.29141
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2317 - precision: 0.5845 - recall: 0.2645 - val_loss: 0.2945 - val_precision: 0.5814 - val_recall: 0.2632 - learning_rate: 8.6071e-05
# Epoch 26/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2325 - precision: 0.5829 - recall: 0.2554
# Epoch 26: val_loss improved from 0.29141 to 0.28781, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2324 - precision: 0.5835 - recall: 0.2559 - val_loss: 0.2878 - val_precision: 0.5820 - val_recall: 0.2616 - learning_rate: 8.5214e-05
# Epoch 27/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2311 - precision: 0.5942 - recall: 0.2658
# Epoch 27: val_loss improved from 0.28781 to 0.28577, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2310 - precision: 0.5945 - recall: 0.2660 - val_loss: 0.2858 - val_precision: 0.5709 - val_recall: 0.2490 - learning_rate: 8.4366e-05
# Epoch 28/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2312 - precision: 0.5905 - recall: 0.2593
# Epoch 28: val_loss improved from 0.28577 to 0.28173, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2311 - precision: 0.5911 - recall: 0.2597 - val_loss: 0.2817 - val_precision: 0.5811 - val_recall: 0.2583 - learning_rate: 8.3527e-05
# Epoch 29/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2309 - precision: 0.5953 - recall: 0.2569
# Epoch 29: val_loss did not improve from 0.28173
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2307 - precision: 0.5960 - recall: 0.2575 - val_loss: 0.2864 - val_precision: 0.5897 - val_recall: 0.2675 - learning_rate: 8.2696e-05
# Epoch 30/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2291 - precision: 0.5953 - recall: 0.2694
# Epoch 30: val_loss did not improve from 0.28173
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2290 - precision: 0.5958 - recall: 0.2695 - val_loss: 0.2835 - val_precision: 0.5775 - val_recall: 0.2378 - learning_rate: 8.1873e-05
# Epoch 31/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2292 - precision: 0.5962 - recall: 0.2563
# Epoch 31: val_loss improved from 0.28173 to 0.28090, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2292 - precision: 0.5966 - recall: 0.2567 - val_loss: 0.2809 - val_precision: 0.6020 - val_recall: 0.2536 - learning_rate: 8.1058e-05
# Epoch 32/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2288 - precision: 0.6022 - recall: 0.2631
# Epoch 32: val_loss improved from 0.28090 to 0.27952, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2288 - precision: 0.6024 - recall: 0.2633 - val_loss: 0.2795 - val_precision: 0.5947 - val_recall: 0.2596 - learning_rate: 8.0252e-05
# Epoch 33/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2277 - precision: 0.6020 - recall: 0.2650
# Epoch 33: val_loss improved from 0.27952 to 0.27595, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2276 - precision: 0.6024 - recall: 0.2652 - val_loss: 0.2760 - val_precision: 0.5938 - val_recall: 0.2543 - learning_rate: 7.9453e-05
# Epoch 34/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2271 - precision: 0.6067 - recall: 0.2697
# Epoch 34: val_loss did not improve from 0.27595
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2271 - precision: 0.6073 - recall: 0.2701 - val_loss: 0.2774 - val_precision: 0.5851 - val_recall: 0.2490 - learning_rate: 7.8663e-05
# Epoch 35/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2269 - precision: 0.6061 - recall: 0.2659
# Epoch 35: val_loss improved from 0.27595 to 0.27242, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2268 - precision: 0.6067 - recall: 0.2664 - val_loss: 0.2724 - val_precision: 0.6020 - val_recall: 0.2626 - learning_rate: 7.7880e-05
# Epoch 36/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2264 - precision: 0.6101 - recall: 0.2690
# Epoch 36: val_loss did not improve from 0.27242
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2263 - precision: 0.6104 - recall: 0.2692 - val_loss: 0.2750 - val_precision: 0.6030 - val_recall: 0.2662 - learning_rate: 7.7105e-05
# Epoch 37/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2262 - precision: 0.6106 - recall: 0.2597
# Epoch 37: val_loss did not improve from 0.27242
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2262 - precision: 0.6111 - recall: 0.2604 - val_loss: 0.2742 - val_precision: 0.6078 - val_recall: 0.2629 - learning_rate: 7.6338e-05
# Epoch 38/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2260 - precision: 0.6105 - recall: 0.2717
# Epoch 38: val_loss improved from 0.27242 to 0.26936, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2259 - precision: 0.6117 - recall: 0.2725 - val_loss: 0.2694 - val_precision: 0.6019 - val_recall: 0.2735 - learning_rate: 7.5578e-05
# Epoch 39/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2254 - precision: 0.6137 - recall: 0.2721
# Epoch 39: val_loss did not improve from 0.26936
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2253 - precision: 0.6142 - recall: 0.2722 - val_loss: 0.2742 - val_precision: 0.6169 - val_recall: 0.2679 - learning_rate: 7.4826e-05
# Epoch 40/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2243 - precision: 0.6222 - recall: 0.2758
# Epoch 40: val_loss did not improve from 0.26936
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2243 - precision: 0.6225 - recall: 0.2760 - val_loss: 0.2732 - val_precision: 0.6176 - val_recall: 0.2622 - learning_rate: 7.4082e-05
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6747 - precision_1: 0.2251 - recall_1: 0.3046
# Epoch 1: val_loss improved from inf to 0.36358, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - loss: 1.6628 - precision_1: 0.2259 - recall_1: 0.3043 - val_loss: 0.3636 - val_precision_1: 0.5685 - val_recall_1: 0.2202 - learning_rate: 1.0000e-04
# Epoch 2/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2922 - precision_1: 0.4195 - recall_1: 0.2490
# Epoch 2: val_loss improved from 0.36358 to 0.36099, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - loss: 0.2919 - precision_1: 0.4203 - recall_1: 0.2489 - val_loss: 0.3610 - val_precision_1: 0.5681 - val_recall_1: 0.2990 - learning_rate: 1.0000e-04
# Epoch 3/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2711 - precision_1: 0.4603 - recall_1: 0.2470
# Epoch 3: val_loss improved from 0.36099 to 0.35967, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2710 - precision_1: 0.4606 - recall_1: 0.2470 - val_loss: 0.3597 - val_precision_1: 0.5727 - val_recall_1: 0.2668 - learning_rate: 1.0000e-04
# Epoch 4/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2616 - precision_1: 0.4939 - recall_1: 0.2407
# Epoch 4: val_loss improved from 0.35967 to 0.35579, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2616 - precision_1: 0.4941 - recall_1: 0.2408 - val_loss: 0.3558 - val_precision_1: 0.5531 - val_recall_1: 0.3293 - learning_rate: 1.0000e-04
# Epoch 5/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2565 - precision_1: 0.5111 - recall_1: 0.2437
# Epoch 5: val_loss improved from 0.35579 to 0.34849, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2565 - precision_1: 0.5112 - recall_1: 0.2437 - val_loss: 0.3485 - val_precision_1: 0.5610 - val_recall_1: 0.3326 - learning_rate: 1.0000e-04
# Epoch 6/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2525 - precision_1: 0.5133 - recall_1: 0.2415
# Epoch 6: val_loss improved from 0.34849 to 0.34519, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2525 - precision_1: 0.5134 - recall_1: 0.2416 - val_loss: 0.3452 - val_precision_1: 0.5518 - val_recall_1: 0.3016 - learning_rate: 1.0000e-04
# Epoch 7/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2496 - precision_1: 0.5163 - recall_1: 0.2353
# Epoch 7: val_loss improved from 0.34519 to 0.34230, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2495 - precision_1: 0.5172 - recall_1: 0.2357 - val_loss: 0.3423 - val_precision_1: 0.5647 - val_recall_1: 0.3228 - learning_rate: 1.0000e-04
# Epoch 8/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2473 - precision_1: 0.5424 - recall_1: 0.2483
# Epoch 8: val_loss improved from 0.34230 to 0.33952, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2473 - precision_1: 0.5424 - recall_1: 0.2484 - val_loss: 0.3395 - val_precision_1: 0.5657 - val_recall_1: 0.3339 - learning_rate: 1.0000e-04
# Epoch 9/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2447 - precision_1: 0.5436 - recall_1: 0.2555
# Epoch 9: val_loss improved from 0.33952 to 0.33570, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2447 - precision_1: 0.5436 - recall_1: 0.2555 - val_loss: 0.3357 - val_precision_1: 0.5802 - val_recall_1: 0.3218 - learning_rate: 1.0000e-04
# Epoch 10/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2447 - precision_1: 0.5462 - recall_1: 0.2473
# Epoch 10: val_loss improved from 0.33570 to 0.32982, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2446 - precision_1: 0.5464 - recall_1: 0.2478 - val_loss: 0.3298 - val_precision_1: 0.5774 - val_recall_1: 0.3124 - learning_rate: 1.0000e-04
# Epoch 11/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2425 - precision_1: 0.5454 - recall_1: 0.2484
# Epoch 11: val_loss improved from 0.32982 to 0.32385, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2425 - precision_1: 0.5455 - recall_1: 0.2485 - val_loss: 0.3239 - val_precision_1: 0.5821 - val_recall_1: 0.3003 - learning_rate: 9.9005e-05
# Epoch 12/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2413 - precision_1: 0.5439 - recall_1: 0.2443
# Epoch 12: val_loss did not improve from 0.32385
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2412 - precision_1: 0.5443 - recall_1: 0.2451 - val_loss: 0.3250 - val_precision_1: 0.5814 - val_recall_1: 0.2990 - learning_rate: 9.8020e-05
# Epoch 13/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2394 - precision_1: 0.5523 - recall_1: 0.2474
# Epoch 13: val_loss improved from 0.32385 to 0.32333, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2394 - precision_1: 0.5524 - recall_1: 0.2477 - val_loss: 0.3233 - val_precision_1: 0.5756 - val_recall_1: 0.3225 - learning_rate: 9.7045e-05
# Epoch 14/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2378 - precision_1: 0.5540 - recall_1: 0.2477
# Epoch 14: val_loss improved from 0.32333 to 0.32054, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2378 - precision_1: 0.5541 - recall_1: 0.2479 - val_loss: 0.3205 - val_precision_1: 0.5798 - val_recall_1: 0.2818 - learning_rate: 9.6079e-05
# Epoch 15/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2385 - precision_1: 0.5563 - recall_1: 0.2478
# Epoch 15: val_loss improved from 0.32054 to 0.31668, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2385 - precision_1: 0.5564 - recall_1: 0.2480 - val_loss: 0.3167 - val_precision_1: 0.5791 - val_recall_1: 0.3124 - learning_rate: 9.5123e-05
# Epoch 16/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2362 - precision_1: 0.5639 - recall_1: 0.2626
# Epoch 16: val_loss did not improve from 0.31668
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2362 - precision_1: 0.5640 - recall_1: 0.2627 - val_loss: 0.3181 - val_precision_1: 0.5723 - val_recall_1: 0.2925 - learning_rate: 9.4176e-05
# Epoch 17/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2358 - precision_1: 0.5703 - recall_1: 0.2593
# Epoch 17: val_loss improved from 0.31668 to 0.31634, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2358 - precision_1: 0.5703 - recall_1: 0.2593 - val_loss: 0.3163 - val_precision_1: 0.5823 - val_recall_1: 0.2834 - learning_rate: 9.3239e-05
# Epoch 18/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2355 - precision_1: 0.5692 - recall_1: 0.2583
# Epoch 18: val_loss improved from 0.31634 to 0.30990, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2355 - precision_1: 0.5694 - recall_1: 0.2584 - val_loss: 0.3099 - val_precision_1: 0.5784 - val_recall_1: 0.2704 - learning_rate: 9.2312e-05
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2346 - precision_1: 0.5753 - recall_1: 0.2704
# Epoch 19: val_loss did not improve from 0.30990
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2346 - precision_1: 0.5753 - recall_1: 0.2704 - val_loss: 0.3124 - val_precision_1: 0.5632 - val_recall_1: 0.2469 - learning_rate: 9.1393e-05
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2344 - precision_1: 0.5760 - recall_1: 0.2566
# Epoch 20: val_loss improved from 0.30990 to 0.30206, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2344 - precision_1: 0.5760 - recall_1: 0.2567 - val_loss: 0.3021 - val_precision_1: 0.5720 - val_recall_1: 0.2537 - learning_rate: 9.0484e-05
# Epoch 21/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2333 - precision_1: 0.5682 - recall_1: 0.2557
# Epoch 21: val_loss did not improve from 0.30206
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2332 - precision_1: 0.5684 - recall_1: 0.2560 - val_loss: 0.3071 - val_precision_1: 0.5623 - val_recall_1: 0.2456 - learning_rate: 8.9583e-05
# Epoch 22/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2318 - precision_1: 0.5867 - recall_1: 0.2644
# Epoch 22: val_loss improved from 0.30206 to 0.29871, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2318 - precision_1: 0.5864 - recall_1: 0.2646 - val_loss: 0.2987 - val_precision_1: 0.5547 - val_recall_1: 0.2329 - learning_rate: 8.8692e-05
# Epoch 23/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2317 - precision_1: 0.5860 - recall_1: 0.2663
# Epoch 23: val_loss improved from 0.29871 to 0.29478, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2317 - precision_1: 0.5861 - recall_1: 0.2664 - val_loss: 0.2948 - val_precision_1: 0.5510 - val_recall_1: 0.2306 - learning_rate: 8.7810e-05
# Epoch 24/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2313 - precision_1: 0.5886 - recall_1: 0.2693
# Epoch 24: val_loss improved from 0.29478 to 0.29386, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2313 - precision_1: 0.5887 - recall_1: 0.2695 - val_loss: 0.2939 - val_precision_1: 0.5502 - val_recall_1: 0.2283 - learning_rate: 8.6936e-05
# Epoch 25/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2315 - precision_1: 0.5904 - recall_1: 0.2711
# Epoch 25: val_loss improved from 0.29386 to 0.28944, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2315 - precision_1: 0.5903 - recall_1: 0.2712 - val_loss: 0.2894 - val_precision_1: 0.5517 - val_recall_1: 0.2277 - learning_rate: 8.6071e-05
# Epoch 26/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2305 - precision_1: 0.5974 - recall_1: 0.2623
# Epoch 26: val_loss improved from 0.28944 to 0.28795, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2305 - precision_1: 0.5971 - recall_1: 0.2628 - val_loss: 0.2880 - val_precision_1: 0.5538 - val_recall_1: 0.2313 - learning_rate: 8.5214e-05
# Epoch 27/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2290 - precision_1: 0.5984 - recall_1: 0.2702
# Epoch 27: val_loss improved from 0.28795 to 0.28136, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2290 - precision_1: 0.5985 - recall_1: 0.2703 - val_loss: 0.2814 - val_precision_1: 0.5480 - val_recall_1: 0.2251 - learning_rate: 8.4366e-05
# Epoch 28/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2283 - precision_1: 0.6009 - recall_1: 0.2722
# Epoch 28: val_loss did not improve from 0.28136
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2283 - precision_1: 0.6010 - recall_1: 0.2721 - val_loss: 0.2848 - val_precision_1: 0.5517 - val_recall_1: 0.2261 - learning_rate: 8.3527e-05
# Epoch 29/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2276 - precision_1: 0.6072 - recall_1: 0.2738
# Epoch 29: val_loss improved from 0.28136 to 0.27867, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2275 - precision_1: 0.6071 - recall_1: 0.2740 - val_loss: 0.2787 - val_precision_1: 0.5484 - val_recall_1: 0.2251 - learning_rate: 8.2696e-05
# Epoch 30/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2281 - precision_1: 0.6080 - recall_1: 0.2735
# Epoch 30: val_loss did not improve from 0.27867
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2281 - precision_1: 0.6080 - recall_1: 0.2736 - val_loss: 0.2793 - val_precision_1: 0.5593 - val_recall_1: 0.2274 - learning_rate: 8.1873e-05
# Epoch 31/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2268 - precision_1: 0.6232 - recall_1: 0.2710
# Epoch 31: val_loss improved from 0.27867 to 0.27704, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2268 - precision_1: 0.6231 - recall_1: 0.2714 - val_loss: 0.2770 - val_precision_1: 0.5537 - val_recall_1: 0.2251 - learning_rate: 8.1058e-05
# Epoch 32/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2253 - precision_1: 0.6222 - recall_1: 0.2811
# Epoch 32: val_loss improved from 0.27704 to 0.27246, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2253 - precision_1: 0.6220 - recall_1: 0.2812 - val_loss: 0.2725 - val_precision_1: 0.5624 - val_recall_1: 0.2274 - learning_rate: 8.0252e-05
# Epoch 33/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2246 - precision_1: 0.6308 - recall_1: 0.2811
# Epoch 33: val_loss did not improve from 0.27246
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2246 - precision_1: 0.6304 - recall_1: 0.2810 - val_loss: 0.2747 - val_precision_1: 0.5649 - val_recall_1: 0.2296 - learning_rate: 7.9453e-05
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2267 - precision_1: 0.6117 - recall_1: 0.2741
# Epoch 34: val_loss improved from 0.27246 to 0.27053, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2267 - precision_1: 0.6116 - recall_1: 0.2741 - val_loss: 0.2705 - val_precision_1: 0.5600 - val_recall_1: 0.2280 - learning_rate: 7.8663e-05
# Epoch 35/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2244 - precision_1: 0.6291 - recall_1: 0.2804
# Epoch 35: val_loss did not improve from 0.27053
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2244 - precision_1: 0.6290 - recall_1: 0.2804 - val_loss: 0.2741 - val_precision_1: 0.5618 - val_recall_1: 0.2264 - learning_rate: 7.7880e-05
# Epoch 36/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2243 - precision_1: 0.6203 - recall_1: 0.2738
# Epoch 36: val_loss improved from 0.27053 to 0.27034, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2243 - precision_1: 0.6203 - recall_1: 0.2738 - val_loss: 0.2703 - val_precision_1: 0.5692 - val_recall_1: 0.2251 - learning_rate: 7.7105e-05
# Epoch 37/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2231 - precision_1: 0.6357 - recall_1: 0.2749
# Epoch 37: val_loss improved from 0.27034 to 0.26561, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2230 - precision_1: 0.6357 - recall_1: 0.2751 - val_loss: 0.2656 - val_precision_1: 0.5623 - val_recall_1: 0.2218 - learning_rate: 7.6338e-05
# Epoch 38/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2220 - precision_1: 0.6381 - recall_1: 0.2802
# Epoch 38: val_loss did not improve from 0.26561
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2220 - precision_1: 0.6379 - recall_1: 0.2801 - val_loss: 0.2666 - val_precision_1: 0.5530 - val_recall_1: 0.2244 - learning_rate: 7.5578e-05
# Epoch 39/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2216 - precision_1: 0.6382 - recall_1: 0.2873
# Epoch 39: val_loss improved from 0.26561 to 0.26476, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2217 - precision_1: 0.6380 - recall_1: 0.2871 - val_loss: 0.2648 - val_precision_1: 0.5687 - val_recall_1: 0.2319 - learning_rate: 7.4826e-05
# Epoch 40/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2212 - precision_1: 0.6386 - recall_1: 0.2873
# Epoch 40: val_loss improved from 0.26476 to 0.26271, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2212 - precision_1: 0.6384 - recall_1: 0.2872 - val_loss: 0.2627 - val_precision_1: 0.5657 - val_recall_1: 0.2257 - learning_rate: 7.4082e-05

# %% [markdown]
# * **Train the model for 20 epochs** (this may take several minutes)**, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3b-i
# Train the model for 20 epochs.


# Train the model for 20 epochs
lstm_history = lstm_model.fit(
    overviews_train_ds,
    validation_data=overviews_valid_ds,
    epochs=20,
    callbacks=[checkpoint_lstm_callback, lr_callback]
)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - loss: 0.6674 - precision: 0.1181 - recall: 0.4616
# Epoch 1: val_loss improved from inf to 0.38797, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 512ms/step - loss: 0.6668 - precision: 0.1182 - recall: 0.4611 - val_loss: 0.3880 - val_precision: 0.5357 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - loss: 0.4885 - precision: 0.1653 - recall: 0.3345
# Epoch 2: val_loss improved from 0.38797 to 0.30640, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 71s 455ms/step - loss: 0.4883 - precision: 0.1654 - recall: 0.3344 - val_loss: 0.3064 - val_precision: 0.4980 - val_recall: 0.4144 - learning_rate: 1.0000e-04
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - loss: 0.4280 - precision: 0.2059 - recall: 0.3113
# Epoch 3: val_loss improved from 0.30640 to 0.27295, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 42s 464ms/step - loss: 0.4278 - precision: 0.2060 - recall: 0.3112 - val_loss: 0.2729 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - loss: 0.3865 - precision: 0.2424 - recall: 0.2928
# Epoch 4: val_loss improved from 0.27295 to 0.25894, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 39s 479ms/step - loss: 0.3864 - precision: 0.2425 - recall: 0.2928 - val_loss: 0.2589 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - loss: 0.3630 - precision: 0.2650 - recall: 0.2699
# Epoch 5: val_loss improved from 0.25894 to 0.25108, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 482ms/step - loss: 0.3630 - precision: 0.2652 - recall: 0.2699 - val_loss: 0.2511 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - loss: 0.3434 - precision: 0.2956 - recall: 0.2534
# Epoch 6: val_loss improved from 0.25108 to 0.24575, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 505ms/step - loss: 0.3433 - precision: 0.2957 - recall: 0.2535 - val_loss: 0.2457 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - loss: 0.3284 - precision: 0.3193 - recall: 0.2360
# Epoch 7: val_loss improved from 0.24575 to 0.24342, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 38s 475ms/step - loss: 0.3283 - precision: 0.3195 - recall: 0.2360 - val_loss: 0.2434 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - loss: 0.3179 - precision: 0.3344 - recall: 0.2363
# Epoch 8: val_loss improved from 0.24342 to 0.24129, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 471ms/step - loss: 0.3179 - precision: 0.3345 - recall: 0.2363 - val_loss: 0.2413 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - loss: 0.3111 - precision: 0.3525 - recall: 0.2272
# Epoch 9: val_loss improved from 0.24129 to 0.23981, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 38s 470ms/step - loss: 0.3111 - precision: 0.3527 - recall: 0.2273 - val_loss: 0.2398 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - loss: 0.3017 - precision: 0.3711 - recall: 0.2232
# Epoch 10: val_loss improved from 0.23981 to 0.23878, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 494ms/step - loss: 0.3017 - precision: 0.3713 - recall: 0.2232 - val_loss: 0.2388 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - loss: 0.2950 - precision: 0.3966 - recall: 0.2265
# Epoch 11: val_loss improved from 0.23878 to 0.23747, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 39s 493ms/step - loss: 0.2950 - precision: 0.3966 - recall: 0.2264 - val_loss: 0.2375 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 9.9005e-05
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - loss: 0.2894 - precision: 0.4071 - recall: 0.2231
# Epoch 12: val_loss improved from 0.23747 to 0.23592, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 38s 473ms/step - loss: 0.2894 - precision: 0.4072 - recall: 0.2231 - val_loss: 0.2359 - val_precision: 0.5399 - val_recall: 0.2259 - learning_rate: 9.8020e-05
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - loss: 0.2857 - precision: 0.4134 - recall: 0.2230
# Epoch 13: val_loss improved from 0.23592 to 0.23477, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 39s 488ms/step - loss: 0.2857 - precision: 0.4135 - recall: 0.2229 - val_loss: 0.2348 - val_precision: 0.5396 - val_recall: 0.2255 - learning_rate: 9.7045e-05
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - loss: 0.2823 - precision: 0.4233 - recall: 0.2230
# Epoch 14: val_loss improved from 0.23477 to 0.23313, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 476ms/step - loss: 0.2823 - precision: 0.4234 - recall: 0.2230 - val_loss: 0.2331 - val_precision: 0.5439 - val_recall: 0.2252 - learning_rate: 9.6079e-05
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - loss: 0.2772 - precision: 0.4420 - recall: 0.2238
# Epoch 15: val_loss improved from 0.23313 to 0.23060, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 501ms/step - loss: 0.2772 - precision: 0.4420 - recall: 0.2239 - val_loss: 0.2306 - val_precision: 0.5772 - val_recall: 0.2176 - learning_rate: 9.5123e-05
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - loss: 0.2734 - precision: 0.4481 - recall: 0.2235
# Epoch 16: val_loss improved from 0.23060 to 0.22727, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 496ms/step - loss: 0.2734 - precision: 0.4483 - recall: 0.2236 - val_loss: 0.2273 - val_precision: 0.6004 - val_recall: 0.2206 - learning_rate: 9.4176e-05
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - loss: 0.2650 - precision: 0.4725 - recall: 0.2304
# Epoch 17: val_loss improved from 0.22727 to 0.22522, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 490ms/step - loss: 0.2650 - precision: 0.4725 - recall: 0.2304 - val_loss: 0.2252 - val_precision: 0.6092 - val_recall: 0.2397 - learning_rate: 9.3239e-05
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - loss: 0.2606 - precision: 0.4869 - recall: 0.2469
# Epoch 18: val_loss improved from 0.22522 to 0.22318, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 39s 483ms/step - loss: 0.2606 - precision: 0.4870 - recall: 0.2470 - val_loss: 0.2232 - val_precision: 0.6221 - val_recall: 0.2325 - learning_rate: 9.2312e-05
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - loss: 0.2570 - precision: 0.4983 - recall: 0.2585
# Epoch 19: val_loss improved from 0.22318 to 0.22251, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 38s 474ms/step - loss: 0.2570 - precision: 0.4984 - recall: 0.2586 - val_loss: 0.2225 - val_precision: 0.6118 - val_recall: 0.2569 - learning_rate: 9.1393e-05
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - loss: 0.2505 - precision: 0.5173 - recall: 0.2639
# Epoch 20: val_loss improved from 0.22251 to 0.22144, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 515ms/step - loss: 0.2505 - precision: 0.5173 - recall: 0.2639 - val_loss: 0.2214 - val_precision: 0.6192 - val_recall: 0.2457 - learning_rate: 9.0484e-05
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - loss: 0.6648 - precision: 0.1138 - recall: 0.4229
# Epoch 1: val_loss improved from inf to 0.37153, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 51s 531ms/step - loss: 0.6642 - precision: 0.1139 - recall: 0.4222 - val_loss: 0.3715 - val_precision: 1.0000 - val_recall: 3.2573e-04 - learning_rate: 1.0000e-04
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - loss: 0.4729 - precision: 0.1559 - recall: 0.2856
# Epoch 2: val_loss improved from 0.37153 to 0.30012, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 79s 499ms/step - loss: 0.4727 - precision: 0.1560 - recall: 0.2855 - val_loss: 0.3001 - val_precision: 0.5464 - val_recall: 0.2205 - learning_rate: 1.0000e-04
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - loss: 0.4188 - precision: 0.1950 - recall: 0.2699
# Epoch 3: val_loss improved from 0.30012 to 0.27741, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 42s 512ms/step - loss: 0.4186 - precision: 0.1951 - recall: 0.2699 - val_loss: 0.2774 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 1.0000e-04
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - loss: 0.3810 - precision: 0.2346 - recall: 0.2597
# Epoch 4: val_loss improved from 0.27741 to 0.26409, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 43s 534ms/step - loss: 0.3809 - precision: 0.2347 - recall: 0.2597 - val_loss: 0.2641 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 1.0000e-04
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 0.3549 - precision: 0.2707 - recall: 0.2500
# Epoch 5: val_loss improved from 0.26409 to 0.25750, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 540ms/step - loss: 0.3548 - precision: 0.2709 - recall: 0.2500 - val_loss: 0.2575 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 1.0000e-04
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 0.3386 - precision: 0.2997 - recall: 0.2437
# Epoch 6: val_loss improved from 0.25750 to 0.25444, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - loss: 0.3386 - precision: 0.2998 - recall: 0.2437 - val_loss: 0.2544 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 1.0000e-04
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - loss: 0.3245 - precision: 0.3289 - recall: 0.2389
# Epoch 7: val_loss improved from 0.25444 to 0.25169, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 510ms/step - loss: 0.3245 - precision: 0.3289 - recall: 0.2389 - val_loss: 0.2517 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 1.0000e-04
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 0.3151 - precision: 0.3622 - recall: 0.2554
# Epoch 8: val_loss improved from 0.25169 to 0.24947, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 42s 518ms/step - loss: 0.3150 - precision: 0.3622 - recall: 0.2554 - val_loss: 0.2495 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 1.0000e-04
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - loss: 0.3062 - precision: 0.3815 - recall: 0.2446
# Epoch 9: val_loss improved from 0.24947 to 0.24818, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 501ms/step - loss: 0.3061 - precision: 0.3815 - recall: 0.2445 - val_loss: 0.2482 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 1.0000e-04
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - loss: 0.3002 - precision: 0.3886 - recall: 0.2328
# Epoch 10: val_loss improved from 0.24818 to 0.24657, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 39s 495ms/step - loss: 0.3002 - precision: 0.3887 - recall: 0.2329 - val_loss: 0.2466 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 1.0000e-04
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - loss: 0.2959 - precision: 0.3992 - recall: 0.2281
# Epoch 11: val_loss improved from 0.24657 to 0.24535, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 39s 483ms/step - loss: 0.2959 - precision: 0.3992 - recall: 0.2281 - val_loss: 0.2453 - val_precision: 0.5431 - val_recall: 0.2238 - learning_rate: 9.9005e-05
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - loss: 0.2906 - precision: 0.4185 - recall: 0.2385
# Epoch 12: val_loss improved from 0.24535 to 0.24402, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 43s 514ms/step - loss: 0.2906 - precision: 0.4185 - recall: 0.2385 - val_loss: 0.2440 - val_precision: 0.5435 - val_recall: 0.2238 - learning_rate: 9.8020e-05
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - loss: 0.2831 - precision: 0.4372 - recall: 0.2378
# Epoch 13: val_loss improved from 0.24402 to 0.24212, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 83s 527ms/step - loss: 0.2831 - precision: 0.4372 - recall: 0.2377 - val_loss: 0.2421 - val_precision: 0.5463 - val_recall: 0.2228 - learning_rate: 9.7045e-05
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - loss: 0.2810 - precision: 0.4376 - recall: 0.2226
# Epoch 14: val_loss improved from 0.24212 to 0.23931, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 500ms/step - loss: 0.2810 - precision: 0.4377 - recall: 0.2227 - val_loss: 0.2393 - val_precision: 0.5807 - val_recall: 0.2156 - learning_rate: 9.6079e-05
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 0.2731 - precision: 0.4544 - recall: 0.2467
# Epoch 15: val_loss improved from 0.23931 to 0.23647, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 487ms/step - loss: 0.2731 - precision: 0.4545 - recall: 0.2468 - val_loss: 0.2365 - val_precision: 0.6028 - val_recall: 0.2140 - learning_rate: 9.5123e-05
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - loss: 0.2664 - precision: 0.4817 - recall: 0.2579
# Epoch 16: val_loss improved from 0.23647 to 0.23276, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 44s 525ms/step - loss: 0.2664 - precision: 0.4817 - recall: 0.2578 - val_loss: 0.2328 - val_precision: 0.6263 - val_recall: 0.2221 - learning_rate: 9.4176e-05
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - loss: 0.2617 - precision: 0.4888 - recall: 0.2626
# Epoch 17: val_loss improved from 0.23276 to 0.23196, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 43s 533ms/step - loss: 0.2616 - precision: 0.4889 - recall: 0.2626 - val_loss: 0.2320 - val_precision: 0.6144 - val_recall: 0.2466 - learning_rate: 9.3239e-05
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 0.2582 - precision: 0.4995 - recall: 0.2660
# Epoch 18: val_loss improved from 0.23196 to 0.22961, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 39s 488ms/step - loss: 0.2581 - precision: 0.4996 - recall: 0.2660 - val_loss: 0.2296 - val_precision: 0.6333 - val_recall: 0.2290 - learning_rate: 9.2312e-05
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 0.2534 - precision: 0.5128 - recall: 0.2768
# Epoch 19: val_loss improved from 0.22961 to 0.22892, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 486ms/step - loss: 0.2534 - precision: 0.5129 - recall: 0.2769 - val_loss: 0.2289 - val_precision: 0.6301 - val_recall: 0.2303 - learning_rate: 9.1393e-05
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 0.2515 - precision: 0.5187 - recall: 0.2719
# Epoch 20: val_loss did not improve from 0.22892
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - loss: 0.2515 - precision: 0.5187 - recall: 0.2719 - val_loss: 0.2300 - val_precision: 0.6012 - val_recall: 0.2700 - learning_rate: 9.0484e-05

# %% [markdown]
# # 4. Evaluation of the models
#
# ### 4.a. CNN Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4a-i


import matplotlib.pyplot as plt
import seaborn as sns

# Extract loss and metrics from the training history
train_loss = cnn_history.history['loss']
val_loss = cnn_history.history['val_loss']
train_precision = cnn_history.history['precision']
val_precision = cnn_history.history['val_precision']
train_recall = cnn_history.history['recall']
val_recall = cnn_history.history['val_recall']

# Number of epochs
epochs = range(1, len(train_loss) + 1)

# Create subplots for Loss, Precision, and Recall
fig, axes = plt.subplots(3, 1, figsize=(10, 12))

# --- Loss Plot ---
sns.lineplot(x=epochs, y=train_loss, ax=axes[0], label='Training Loss')
sns.lineplot(x=epochs, y=val_loss, ax=axes[0], label='Validation Loss')
axes[0].set_title('CNN Training and Validation Loss')
axes[0].set_ylabel('Loss')
axes[0].legend()

# --- Precision Plot ---
sns.lineplot(x=epochs, y=train_precision, ax=axes[1], label='Training Precision')
sns.lineplot(x=epochs, y=val_precision, ax=axes[1], label='Validation Precision')
axes[1].set_title('CNN Training and Validation Precision')
axes[1].set_ylabel('Precision')
axes[1].legend()

# --- Recall Plot ---
sns.lineplot(x=epochs, y=train_recall, ax=axes[2], label='Training Recall')
sns.lineplot(x=epochs, y=val_recall, ax=axes[2], label='Validation Recall')
axes[2].set_title('CNN Training and Validation Recall')
axes[2].set_ylabel('Recall')
axes[2].set_xlabel('Epoch')
axes[2].legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-06957166a5d4> in <cell line: 10>()
#       8 train_loss = cnn_history.history['loss']
#       9 val_loss = cnn_history.history['val_loss']
# ---> 10 train_precision = cnn_history.history['precision']
#      11 val_precision = cnn_history.history['val_precision']
#      12 train_recall = cnn_history.history['recall']
#
# KeyError: 'precision'

# %% [markdown]
# * **Load the best weights from your model checkpoint, and create plots demonstrating the classification performance for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %% [markdown]
# ### 4.b. LSTM Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4b-i


import matplotlib.pyplot as plt
import seaborn as sns

# Set a visually appealing style with a colorblind-friendly palette
sns.set_style("whitegrid")
sns.set_palette("colorblind")

# Extract loss and metrics from the training history
train_loss = lstm_history.history['loss']
val_loss = lstm_history.history['val_loss']
train_precision = lstm_history.history['precision']
val_precision = lstm_history.history['val_precision']
train_recall = lstm_history.history['recall']
val_recall = lstm_history.history['val_recall']

# Number of epochs
epochs = range(1, len(train_loss) + 1)

# Create subplots for Loss, Precision, and Recall
fig, axes = plt.subplots(3, 1, figsize=(10, 12))

# --- Loss Plot ---
sns.lineplot(x=epochs, y=train_loss, ax=axes[0], label='Training Loss')
sns.lineplot(x=epochs, y=val_loss, ax=axes[0], label='Validation Loss')
axes[0].set_title('LSTM Training and Validation Loss')
axes[0].set_ylabel('Loss')
axes[0].legend()

# --- Precision Plot ---
sns.lineplot(x=epochs, y=train_precision, ax=axes[1], label='Training Precision')
sns.lineplot(x=epochs, y=val_precision, ax=axes[1], label='Validation Precision')
axes[1].set_title('LSTM Training and Validation Precision')
axes[1].set_ylabel('Precision')
axes[1].legend()

# --- Recall Plot ---
sns.lineplot(x=epochs, y=train_recall, ax=axes[2], label='Training Recall')
sns.lineplot(x=epochs, y=val_recall, ax=axes[2], label='Validation Recall')
axes[2].set_title('LSTM Training and Validation Recall')
axes[2].set_ylabel('Recall')
axes[2].set_xlabel('Epoch')
axes[2].legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.c. Produce examples for the report
#
# * First, load the best weights from your checkpoints of both your models.
#
# * Choose a few films from the dataset, plot their posters and print their overviews. Use these example films to demonstrate the classification performance of the CNN model on their posters and of the LSTM model on their overview.
#
# * Be sure to demonstrate the results of the multi-label classification. Compare, for each example film, the top three most probable genres predicted by the CNN and the top three most probable genres predicted by the LSTM with the ground truth genres.
#
# * Include these examples in your report, and critically evaluate on the performance of the model across the classes.

# %%
# CodeGrade Tag Ex4c

# Load best weights for CNN model
cnn_model.load_weights(checkpoint_cnn_filepath)

# Evaluate CNN model on test set
cnn_results = cnn_model.evaluate(posters_valid_ds, verbose=0)

# Load best weights for LSTM model
lstm_model.load_weights(checkpoint_lstm_filepath)

# Evaluate LSTM model on test set
lstm_results = lstm_model.evaluate(overviews_valid_ds, verbose=0)

# Print evaluation results
print("CNN Results:", dict(zip(cnn_model.metrics_names, cnn_results)))
print("LSTM Results:", dict(zip(lstm_model.metrics_names, lstm_results)))
# Out:
# CNN Results: {'loss': 0.26936301589012146, 'compile_metrics': 0.6018922924995422}
# LSTM Results: {'loss': 0.2214447408914566, 'compile_metrics': 0.6191666722297668}

# %% [markdown]
# Example

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import matplotlib.image as mpimg

# Load best weights for CNN and LSTM models
cnn_model.load_weights(checkpoint_cnn_filepath)
lstm_model.load_weights(checkpoint_lstm_filepath)

# Choose example films
example_film_indices = [2, 15, 33, 60, 88]
example_films = data_test.iloc[example_film_indices]

# Function to get top predictions and probabilities
def get_top_predictions(predictions, genres, num_predictions=3):
    top_indices = np.argsort(predictions)[-num_predictions:][::-1]
    top_genres = genres[top_indices]
    top_probs = predictions[top_indices]
    return top_genres, top_probs

# Loop through example films
for index, film in example_films.iterrows():
    film_id = film['Id']
    overview = film['Overview']
    ground_truth_genres = film[genres].to_numpy().astype(bool)
    ground_truth_genre_names = genres[ground_truth_genres]

    # Display film poster
    image_path = f"{img_loc}/{film_id}.jpg"
    img = mpimg.imread(image_path)
    plt.figure(figsize=(5, 5))
    plt.imshow(img)
    plt.title(f"Film Poster: {film_id}")
    plt.axis('off')
    plt.show()

    # Print overview
    print(f"Overview: {overview}")

    # Get CNN predictions
    image = tf.io.read_file(image_path)
    image = tf.io.decode_jpeg(image)
    cnn_input = tf.expand_dims(img_process(image, None)[0], axis=0)
    cnn_predictions = cnn_model.predict(cnn_input)[0]
    cnn_top_genres, cnn_top_probs = get_top_predictions(cnn_predictions, genres)

    # Get LSTM predictions
    lstm_input = tf.expand_dims(overview, axis=0)
    lstm_predictions = lstm_model.predict(lstm_input)[0]
    lstm_top_genres, lstm_top_probs = get_top_predictions(lstm_predictions, genres)

    # Display predictions in a table format
    print("-" * 30)
    print(f"{'Model':<10} {'Top Genres':<25} {'Probabilities':<20}")
    print("-" * 30)
    for i in range(len(cnn_top_genres)):
        print(f"{'CNN':<10} {cnn_top_genres[i]:<25} {cnn_top_probs[i]:.4f}")
    for i in range(len(lstm_top_genres)):
        print(f"{'LSTM':<10} {lstm_top_genres[i]:<25} {lstm_top_probs[i]:.4f}")
    print("-" * 30)
    print(f"Ground Truth Genres: {', '.join(ground_truth_genre_names)}")
    print("-" * 30 + "\n")
# Out:
# Overview: An afterlife therapist and his daughter meet a friendly young ghost when they move into a crumbling mansion in order to rid the premises of wicked spirits.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 854ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 777ms/step
# ------------------------------
# Model      Top Genres                Probabilities
# ------------------------------
# CNN        Drama                     0.4989
# CNN        Comedy                    0.3973
# CNN        Action                    0.3809
# LSTM       Drama                     0.3708
# LSTM       Action                    0.3477
# LSTM       Adventure                 0.2890
# ------------------------------
# Ground Truth Genres: Comedy, Family, Fantasy
# ------------------------------
# Overview: ACP Prithviraj is an honest cop. When he arrests the Chief Minister's son for assaulting a girl, the minister tries his best to create havoc in Prithviraj's life.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ------------------------------
# Model      Top Genres                Probabilities
# ------------------------------
# CNN        Drama                     0.5584
# CNN        Comedy                    0.5224
# CNN        Romance                   0.4150
# LSTM       Drama                     0.6095
# LSTM       Comedy                    0.4707
# LSTM       Romance                   0.2011
# ------------------------------
# Ground Truth Genres: Action, Drama, Thriller
# ------------------------------
# Overview: Two radio voice actors are getting married. Larry has fits of fear. A shrink needs 36 hours to scare him to death and cure him - a family reunion at a scary family castle.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# ------------------------------
# Model      Top Genres                Probabilities
# ------------------------------
# CNN        Drama                     0.4924
# CNN        Action                    0.3840
# CNN        Thriller                  0.3745
# LSTM       Drama                     0.6593
# LSTM       Comedy                    0.5176
# LSTM       Romance                   0.2336
# ------------------------------
# Ground Truth Genres: Comedy, Horror, Musical
# ------------------------------
# Overview: Jeff Marx wants to study medicine and become a physician. However, his grades are far from enough to get him into an American medical school. But instead he gets a chance to study medicine ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# ------------------------------
# Model      Top Genres                Probabilities
# ------------------------------
# CNN        Drama                     0.6345
# CNN        Comedy                    0.4354
# CNN        Romance                   0.4092
# LSTM       Drama                     0.4727
# LSTM       Comedy                    0.3716
# LSTM       Action                    0.2563
# ------------------------------
# Ground Truth Genres: Comedy
# ------------------------------
# Overview: A former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ------------------------------
# Model      Top Genres                Probabilities
# ------------------------------
# CNN        Drama                     0.6623
# CNN        Action                    0.3712
# CNN        Crime                     0.3701
# LSTM       Drama                     0.6421
# LSTM       Comedy                    0.4839
# LSTM       Romance                   0.2266
# ------------------------------
# Ground Truth Genres: Crime, Drama
# ------------------------------
